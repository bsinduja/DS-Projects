# %%
import pandas as pd
dataset=pd.read_csv("C:/Users/Sinduja/Documents/AI_sinduja/Hope_AI/MLDSCapstoneProject/ThyroidCancerRecurrencePredictionProject/DataPreprocessing/cleaned_dataset.csv")

from Univariate import Univariate as Uni
quan,qual=Uni.quanQual(dataset)

descriptive=Uni.Univariate(dataset,quan)
print(descriptive)
# Out:
#                Age
# Mean     40.866841
# Median        37.0
# Mode            31
# Q1:25%        29.0
# Q2:50%        37.0
# Q3:75%        51.0
# 99%           80.0
# Q4:100%       82.0
# IQR           22.0
# 1.5rule       33.0
# Lesser        -4.0
# Greater       84.0
# Min             15
# Max             82

# %%
prep=pd.get_dummies(dataset,drop_first=True)
prep.corr()
# Out:
#                                                        Age  Gender_M  \
# Age                                               1.000000  0.186457
# Gender_M                                          0.186457  1.000000
# Smoking_Yes                                       0.309536  0.621886
# Hx Smoking_Yes                                    0.134531  0.175755
# Hx Radiothreapy_Yes                               0.176588  0.235865
# Thyroid Function_Clinical Hypothyroidism         -0.013999 -0.041803
# Thyroid Function_Clinical Hypothyroidism'        -0.033400 -0.024407
# Thyroid Function_Euthyroid                       -0.028367 -0.050344
# Thyroid Function_Subclinical Hyperthyroidism     -0.077259  0.017084
# Thyroid Function_Subclinical Hyperthyroidism'    -0.036785 -0.024407
# Thyroid Function_Subclinical Hypothyroidism       0.107540  0.096102
# Thyroid Function_Subclinical Hypothyroidism'     -0.013090 -0.024407
# Physical Examination_Multinodular goiter          0.102101  0.084366
# ...

# %%
from dython.nominal import associations
import pandas as pd


# Generate matrix and heatmap automatically
results = associations(dataset, nominal_columns='auto',figsize=(10,8),cmap='Oranges')
corr_matrix = results['corr']
#results

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calcVIF(X):
    vif=pd.DataFrame()
    vif['variables']=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return vif

# %%
X=dataset.drop('Recurred', 1)
calcVIF(X)
# Out:
# C:\Anaconda\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25864\1452347197.py in <module>
#       1 X=dataset.drop('Recurred', 1)
# ----> 2 calcVIF(X)
#
# ~\AppData\Local\Temp\ipykernel_25864\1462849845.py in calcVIF(X)
#       3     vif=pd.DataFrame()
#       4     vif['variables']=X.columns
# ----> 5     vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
#       6     return vif
#
# ~\AppData\Local\Temp\ipykernel_25864\1462849845.py in <listcomp>(.0)
#       3     vif=pd.DataFrame()
#       4     vif['variables']=X.columns
# ...
